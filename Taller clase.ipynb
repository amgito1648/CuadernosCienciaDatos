# %%
**dos capas 32  16  **  trabajar con optiizador adam utilizar 0.1 de learning rate. de 5 a 15 epocas, las que quiera, utilizar la funcion de perdida SparseCategoricalCrosentropy(from_logits=True), dado que es una clasificacion, la metrica a utlizar es accuracy

# %%
#importe la libreria de numpy pandas, mathprolit, tensorflow, keras

# %%
import numpy as np 
import pandas as pd  
import matplotlib.pyplot as plt  
import tensorflow as tf

# %%
# Imprima las versiones de python  de tensor flow y de keras

# %%
import sys
import tensorflow as tf
import keras

# Imprimir versión de Python
print(f"Versión de Python: {sys.version}")

# Imprimir versión de TensorFlow
print(f"Versión de TensorFlow: {tf.__version__}")

# Imprimir versión de Keras
print(f"Versión de Keras: {keras.__version__}")
